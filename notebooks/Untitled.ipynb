# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(15,8))
df = pd.DataFrame(np.random.randint(20,size=(20,1)),columns=['data'])
df.plot(ax=ax)
